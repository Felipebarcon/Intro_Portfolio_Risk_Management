# %%
import pandas as pd
import matplotlib.pyplot as plt
from fontTools.varLib.mutator import percents

# %%
# Read in the csv file and parse dates
StockPrices = pd.read_csv('data/AAPL.csv', parse_dates=['Date'])

# %%
StockPrices = StockPrices.sort_values(by='Date')

# %%
StockPrices.set_index('Date', inplace=True)

# %%
# Print only the first five rows of StockPrices
print(StockPrices.head(5))
# Out:
#                 Open      High       Low     Close  Adj Close       Volume
# Date
# 1980-12-12  0.513393  0.515625  0.513393  0.513393   0.023106  117258400.0
# 1980-12-15  0.488839  0.488839  0.486607  0.486607   0.021900   43971200.0
# 1980-12-16  0.453125  0.453125  0.450893  0.450893   0.020293   26432000.0
# 1980-12-17  0.462054  0.464286  0.462054  0.462054   0.020795   21610400.0
# 1980-12-18  0.475446  0.477679  0.475446  0.475446   0.021398   18362400.0

# %%
# Calculate the daily returns of the adjusted close price
StockPrices['Open'] = StockPrices['Close'].pct_change()

# %%
# Check the first five rows of StockPrices
print(StockPrices.head(5))
# Out:
#                 Open      High       Low     Close  Adj Close       Volume  \
# Date
# 1980-12-12       NaN  0.515625  0.513393       NaN   0.023106  117258400.0
# 1980-12-15       NaN  0.488839  0.486607 -0.052194   0.021900   43971200.0
# 1980-12-16  0.405883  0.453125  0.450893 -0.073379   0.020293   26432000.0
# 1980-12-17 -1.337121  0.464286  0.462054  0.024738   0.020795   21610400.0
# 1980-12-18  0.172198  0.477679  0.475446  0.028997   0.021398   18362400.0
#
#              Returns
# Date
# 1980-12-12       NaN
# 1980-12-15 -0.052194
# 1980-12-16 -0.073379
# 1980-12-17  0.024738
# 1980-12-18  0.028997

# %%
plt.hist(StockPrices["Returns"].dropna(), bins=75, density=False)
plt.show()

# %%
# Plot the returns column over time
StockPrices['Returns'].plot()
plt.show()

# %%
# Convert the decimal returns into percentage returns
# Out:
# /var/folders/5z/mr0h6p2s6t34qv9rx3x9896w0000gn/T/ipykernel_67231/3232105950.py:2: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   percent_returns = StockPrices.pct_change()

# %%
# Drop the missing values
returns_plot = StockPrices['Returns'].pct_change()
returns_plot.plot()
plt.show()
